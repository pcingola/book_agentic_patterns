# %% [markdown]
# # RAG: Load Vector Database
#
# This notebook loads book chapters into a Chroma vector database using pydantic-ai embeddings.
# Run this notebook once to populate the database before using the query notebook.

# %% [markdown]
# ## Initialize

# %%
from pathlib import Path

from agentic_patterns.core.config.config import MAIN_PROJECT_DIR
from agentic_patterns.core.doc_ingestion.models import DocumentProvenance
from agentic_patterns.core.utils import relative_to_home
from agentic_patterns.core.vectordb import get_vector_db, load_vectordb_settings
from agentic_patterns.core.vectordb.chunking import chunk_by_paragraphs

# %%
DOCS_DIR = MAIN_PROJECT_DIR / "tests" / "data" / "books"
print(f"Books directory: {relative_to_home(DOCS_DIR)}")

# %% [markdown]
# ## Vector-db: ETL (Extract, Transform, Load)
#
# Creates/loads a Chroma vector database collection named 'books'. The database persists to the location defined in config.yaml.

# %%
vdb = get_vector_db("books")

# Show database location
settings = load_vectordb_settings(MAIN_PROJECT_DIR / "config.yaml")
db_path = Path(settings.get_vectordb().persist_directory)
print(f"Database directory: {relative_to_home(db_path)}")

# %%
# Check if the database needs to be populated
count = vdb.count()
create_vdb = count == 0
print(f"Collection has {count} documents. Need to populate: {create_vdb}")

# %% [markdown]
# ## Load documents

# %%
if create_vdb:
    count_added = 0
    for txt_file in DOCS_DIR.glob("*.txt"):
        print(f"Reading file '{relative_to_home(txt_file)}'")
        provenance = DocumentProvenance(original_file=txt_file, source=txt_file.stem)
        chunks = chunk_by_paragraphs(txt_file.read_text(), provenance, min_lines=3)
        added = vdb.ingest(chunks, force=False)
        count_added += added
        print(f"  {added} chunks added")
    print(f"\nTotal documents added: {count_added}")
    assert count_added > 0, (
        f"No documents added. Check books directory: {relative_to_home(DOCS_DIR)}"
    )
else:
    print("Database already populated, skipping load.")

# %%
print(f"Final document count: {vdb.count()}")
