# %% [markdown]
# # Agent V5: The Full Agent
#
# A monolithic agent with unified task orchestration. All sub-agent work flows through the
# `AgentRunner`, giving us concurrent execution and cancellation.
#
# Same delegation tools as V4:
# - `task_launch(description, prompt, agent_name)` -- synchronous delegation (default)
# - `task_launch(description, prompt, agent_name, run_in_background=True)` -- fire-and-forget, returns agent_id
# - `task_output(agent_id)` -- collect result from a background agent (blocks by default)
# - `task_stop(agent_id)` -- cancel a running background agent
#
# The Full Agent's prompt adds a dedicated "Background tasks" section with explicit
# guidance on when to use synchronous vs asynchronous delegation. Between turns,
# completed background agents are automatically injected into the prompt.
#
# **Prerequisite:** Run `scripts/db_ingest_bookstore_sqlite.sh` to create the bookstore database.

# %%
from agentic_patterns.core.agents import AgentSpec, OrchestratorAgent
from agentic_patterns.core.workspace import clean_up_session

# %% [markdown]
# ## Agent Definition
#
# The full agent uses the same tools and sub-agents as the Coordinator but with a different
# prompt. The `OrchestratorAgent` creates an `AgentRunner` internally when `sub_agents` are
# present, and auto-adds `task_launch`, `task_output`, `task_stop` (delegation) plus
# `task_create`, `task_update`, `task_get`, `task_list_all` (task management).

# %%
spec = AgentSpec.from_config("full_agent")
print(spec)

# %%
clean_up_session()
agent = OrchestratorAgent(spec, verbose=True)

# %% [markdown]
# ## Turn 1: Synchronous Delegation
#
# Ask about data in the bookstore database. The agent should use `task_launch` in foreground
# mode (the default) since it needs the result immediately to continue.

# %%
async with agent:
    prompt_1 = """Query the bookstore database: how many books are there,
what genres are represented, and what is the average price per genre?
Save the per-genre results to a CSV file."""

    result_1 = await agent.run(prompt_1)

    print("\n--- Agent Output ---")
    print(result_1.output)

# %% [markdown]
# ## Turn 2: Parallel Background Tasks
#
# Ask the agent to do multiple independent tasks. It should use `task_launch` with
# `run_in_background=True` to run them in parallel (SQL query and data visualization),
# then `task_output` to collect results, and finally assemble a report.

# %%
async with agent:
    prompt_2 = """I need two things done in parallel:
1. Query the bookstore database for the top 5 most expensive books with their authors and genres.
2. Create a bar chart showing the average price per genre (save as /workspace/avg_price_by_genre.png).

Submit both as background tasks, then check on them. Once both are done,
write a markdown report at /workspace/bookstore_report.md combining all findings."""

    result_2 = await agent.run(prompt_2)

    print("\n--- Agent Output ---")
    print(result_2.output)

# %% [markdown]
# ## Verify Workspace

# %%
from agentic_patterns.core.workspace import list_workspace_files, read_from_workspace

for path in sorted(list_workspace_files("*")):
    try:
        content = read_from_workspace(path)
    except UnicodeDecodeError:
        content = "<binary file>"
    print(f"--- {path} ---")
    print(content)
    print()
