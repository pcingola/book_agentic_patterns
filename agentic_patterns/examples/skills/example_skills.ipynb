# %% [markdown]
# # Skills and Progressive Disclosure
#
# Skills are reusable capability packages that reveal detail only when needed. A skill contains instructions (in SKILL.md) and optionally bundled scripts.
#
# This example shows an agent that discovers a checksum skill, activates it, and runs its script to compute a hash the LLM cannot produce on its own.

# %%
from pathlib import Path
from agentic_patterns.core.agents import get_agent, run_agent
from agentic_patterns.core.skills.registry import SkillRegistry

# %% [markdown]
# ## Setup: Discover Skills
#
# Discovery loads only metadata (name + description). Full instructions stay on disk until needed.

# %%
skills_root = Path("skills-demo")
registry = SkillRegistry()
registry.discover([skills_root])

print("Discovered skills:")
for meta in registry.list_all():
    print(f"  {meta}")

# %% [markdown]
# ## Skill Tools from the Core Library
#
# `registry.get_all_tools(allow_local=True)` returns the tools that implement progressive disclosure:
# - `activate_skill` -- loads the full SKILL.md instructions into the agent's context (Tier 2)
# - `run_skill_script` -- executes a script bundled with an activated skill (Tier 3)
# - `read_skill_resource` -- reads a reference or asset file from an activated skill (Tier 3)
#
# No custom tool code is needed. The core library provides the complete progressive disclosure infrastructure.

# %%
from agentic_patterns.core.skills.models import SkillEvent


def on_skill_event(event: SkillEvent) -> None:
    print(f"  [SKILL {event.event_type.value.upper()}] {event.skill_name}", end="")
    if event.payload:
        details = ", ".join(f"{k}={v}" for k, v in event.payload.items())
        print(f" ({details})")
    else:
        print()


registry.on_event = on_skill_event

skill_tools = registry.get_all_tools(allow_local=True)

for tool in skill_tools:
    print(f"  {tool.__name__}: {tool.__doc__}")

# %% [markdown]
# ## Create the Agent
#
# `registry.system_prompt()` returns the skill catalog and usage instructions as a single block. No boilerplate needed.

# %%
system_prompt = f"""You are an assistant with access to skills.

{registry.system_prompt()}"""

agent = get_agent(system_prompt=system_prompt, tools=skill_tools)

# %% [markdown]
# ## Run the Agent
#
# Watch for `[SKILL ACTIVATE]` and `[SKILL EXEC]` lines printed by the `on_event` hook.

# %%
prompt = "Compute the SHA-256 checksum of 'hello world' and verify it against the known test vectors."

agent_run, nodes = await run_agent(agent, prompt, verbose=True)

print(f"\n--- Final Response ---\n{agent_run.result.output}")

# %% [markdown]
# ## What Happened
#
# The agent:
# 1. Saw the skill catalog in its system prompt (metadata only -- Tier 1)
# 2. Called `activate_skill("checksum")` to load full instructions (Tier 2)
# 3. Called `run_skill_script("checksum", "checksum.py", "hello world")` to compute the hash (Tier 3)
# 4. Called `read_skill_resource("checksum", "reference", "test_vectors.md")` to load the known values (Tier 3)
# 5. Compared the computed hash against the reference and reported the result
#
# Three tiers of progressive disclosure in action: the catalog told the agent the skill exists, activation revealed how to use it, and the script and reference provided the actual data.
