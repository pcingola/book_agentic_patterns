# %% [markdown]
# # Skills and Progressive Disclosure
#
# Skills are reusable capability packages that reveal detail only when needed. A skill contains instructions (in SKILL.md) and optionally bundled scripts.
#
# This example shows an agent that discovers available skills, activates one, and runs its script -- all through tools provided by the core library.

# %%
from pathlib import Path
from agentic_patterns.core.agents import get_agent, run_agent
from agentic_patterns.core.skills.registry import SkillRegistry
from agentic_patterns.core.skills.tools import get_all_tools, list_available_skills

# %% [markdown]
# ## Setup: Discover Skills
#
# Discovery loads only metadata (name + description). Full instructions stay on disk until needed.

# %%
skills_root = Path("skills-demo")
registry = SkillRegistry()
registry.discover([skills_root])

print("Discovered skills:")
for meta in registry.list_all():
    print(f"  {meta}")

# %% [markdown]
# ## Skill Tools from the Core Library
#
# `get_all_tools(registry)` returns two tools:
# - `activate_skill` -- loads the full SKILL.md instructions into the agent's context (Tier 2)
# - `run_skill_script` -- executes a script bundled with an activated skill (Tier 3)
#
# No custom tool code is needed. The core library provides the complete progressive disclosure infrastructure.

# %%
skill_tools = get_all_tools(registry)

for tool in skill_tools:
    print(f"  {tool.__name__}: {tool.__doc__}")

# %% [markdown]
# ## Create the Agent
#
# The system prompt includes the skill catalog. The agent must activate a skill before running its scripts.

# %%
skill_catalog = list_available_skills(registry)

system_prompt = f"""You are an assistant with access to skills.

Available skills:
{skill_catalog}

To use a skill:
1. Call activate_skill(skill_name) to load its instructions
2. Follow the instructions -- they will tell you what scripts are available
3. Use run_skill_script(skill_name, script_name, args) to execute them

You must activate a skill before running its scripts."""

agent = get_agent(system_prompt=system_prompt, tools=skill_tools)

# %% [markdown]
# ## Run the Agent
#
# Watch for `[SKILL ACTIVATED]` and `[EXECUTE]` markers in the output.

# %%
prompt = "Review this Python code for security issues: `data = eval(user_input)`"

agent_run, nodes = await run_agent(agent, prompt, verbose=True)

print(f"\n--- Final Response ---\n{agent_run.result.output}")

# %% [markdown]
# ## What Happened
#
# The agent:
# 1. Saw the skill catalog in its system prompt (metadata only -- Tier 1)
# 2. Called `activate_skill("code-review")` to load full instructions (Tier 2)
# 3. Read the instructions and learned the skill has an `analyze.py` script
# 4. Called `run_skill_script("code-review", "analyze.py", ...)` to execute it (Tier 3)
# 5. Reported findings based on the script output
#
# Both `activate_skill` and `run_skill_script` come from the core library's `get_all_tools()`. The skill provided *instructions and scripts* -- the library provided the infrastructure to load and execute them.
